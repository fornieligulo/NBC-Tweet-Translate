# %% [markdown]
# <a href="https://colab.research.google.com/github/fornieligulo/NBC-Tweet-Translate/blob/main/Langkah3_SKRIPSI_Processing_Data_Siap_Indonesia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MENGHITUNG CLASSIFIER TWEET | TRANSLATE | HITUNG SENTIMEN**

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
def load_data():
    data = pd.read_csv('Data_Hasil_Processing_Tweet.csv')
    return data

tweet_df = load_data()
tweet_df.head()
# Out:
#          date      time        username  \
# 0  29/01/2023   6:37:20    pejuangmslim
# 1  29/01/2023  18:04:53         lmh1640
# 2  29/01/2023  23:28:50      irfansambo
# 3  20/01/2023   7:40:23      johnyjoe76
# 4  26/01/2023   9:43:32  pr_tasikmalaya
#
#                                                tweet
# 0  rakyat percaya institusi semenjak sambo gak ke...
# 1  tidak suka mulia drpd benci oke logika nggak b...
# 2                 amin moga sakinah mawadah warohmah
# 3  abai pasal eliezer orang sipil perintah bintan...
# 4  abdi buah dakwa bunuh bharada e serah putus ma...

# %%
#definisi dataframe
#ubah dataframe sesuai column kalian
df  = pd.DataFrame(tweet_df[['date','time','username','tweet']])
df
# Out:
#              date      time         username  \
# 0      29/01/2023   6:37:20     pejuangmslim
# 1      29/01/2023  18:04:53          lmh1640
# 2      29/01/2023  23:28:50       irfansambo
# 3      20/01/2023   7:40:23       johnyjoe76
# 4      26/01/2023   9:43:32   pr_tasikmalaya
# ...           ...       ...              ...
# 14880  08/01/2023  18:41:30     frhyan_abdlh
# 14881  28/12/2022  11:24:42   bayusteelheart
# 14882  16/01/2023  10:32:32       anisanbl12
# 14883  30/01/2023   6:45:50     xxrabbitstar
# 14884  18/01/2023  17:55:49  zoelhelmilubis1
#
#                                                    tweet
# 0      rakyat percaya institusi semenjak sambo gak ke...
# 1      tidak suka mulia drpd benci oke logika nggak b...
# 2                     amin moga sakinah mawadah warohmah
# 3      abai pasal eliezer orang sipil perintah bintan...
# 4      abdi buah dakwa bunuh bharada e serah putus ma...
# ...                                                  ...
# ...

# %%
# !pip install VaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 KB 3.6 MB/s eta 0:00:00
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
scores = [analyser.polarity_scores(x) for x in tweet_df['tweet']]
print(scores)
tweet_df['Compound_Score'] = [x['compound'] for x in scores]

tweet_df.head(5)
# Out:
# [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.5106}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
# ...

# %%
tweet_df.loc[tweet_df['Compound_Score'] < 0, 'Sentiments'] = 'Negatif'
tweet_df.loc[tweet_df['Compound_Score'] == 0, 'Sentiments'] = 'Netral'
tweet_df.loc[tweet_df['Compound_Score'] > 0, 'Sentiments'] = 'Positif'
tweet_df.head()
# Out:
#          date      time        username  \
# 0  29/01/2023   6:37:20    pejuangmslim
# 1  29/01/2023  18:04:53         lmh1640
# 2  29/01/2023  23:28:50      irfansambo
# 3  20/01/2023   7:40:23      johnyjoe76
# 4  26/01/2023   9:43:32  pr_tasikmalaya
#
#                                                tweet  Compound_Score  \
# 0  rakyat percaya institusi semenjak sambo gak ke...          0.0000
# 1  tidak suka mulia drpd benci oke logika nggak b...          0.0000
# 2                 amin moga sakinah mawadah warohmah          0.0000
# 3  abai pasal eliezer orang sipil perintah bintan...         -0.5106
# 4  abdi buah dakwa bunuh bharada e serah putus ma...          0.0000
#
#   Sentiments
# 0     Netral
# 1     Netral
# 2     Netral
# 3    Negatif
# 4     Netral

# %%
tweet_df.to_csv('Data_sentiment_processing_tweet indonesia.csv',encoding='utf8', index=False)

# %%
s = pd.value_counts(tweet_df['Sentiments'])
ax = s.plot.bar()
n = len(tweet_df.index)
print(n)
for p in ax.patches:
  ax.annotate(str(round(p.get_height() / n*100, 2)) + '%', (p.get_x() * 1.005, p.get_height() *1.005))
# Out:
# 14885

# %%
import pandas as pandas
import pandas as pd

def load_data():
  data = pd.read_csv('Data_sentiment_processing_tweet indonesia.csv')
  return data

# %%
tweet = load_data()
tweet.head()
# Out:
#          date      time        username  \
# 0  29/01/2023   6:37:20    pejuangmslim
# 1  29/01/2023  18:04:53         lmh1640
# 2  29/01/2023  23:28:50      irfansambo
# 3  20/01/2023   7:40:23      johnyjoe76
# 4  26/01/2023   9:43:32  pr_tasikmalaya
#
#                                                tweet  Compound_Score  \
# 0  rakyat percaya institusi semenjak sambo gak ke...          0.0000
# 1  tidak suka mulia drpd benci oke logika nggak b...          0.0000
# 2                 amin moga sakinah mawadah warohmah          0.0000
# 3  abai pasal eliezer orang sipil perintah bintan...         -0.5106
# 4  abdi buah dakwa bunuh bharada e serah putus ma...          0.0000
#
#   Sentiments
# 0     Netral
# 1     Netral
# 2     Netral
# 3    Negatif
# 4     Netral

# %%
s = pd.value_counts(tweet['Sentiments'])
ax = s.plot.bar()
n = len(tweet.index)
print(n)
for p in ax.patches:
  ax.annotate(str(round(p.get_height() / n*100, 2)) + '%', (p.get_x() * 1.005, p.get_height() *1.005))
# Out:
# 14885
